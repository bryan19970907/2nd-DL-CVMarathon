# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/drive') # 將 google drive 掛載在 colob，
# %cd 'drive/My Drive/cv/day42/cupoy_cv_part4'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/cv/day42/cupoy_cv_part4

# %%
# !ls
# Out:
# IdLookupTable.csv     test.csv	training.csv
# SampleSubmission.csv  test.zip	training.zip

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# https://zhuanlan.zhihu.com/p/89535746
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=80, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/80
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0072 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00233, saving model to best_weights.h5
# Epoch 2/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00233 to 0.00193, saving model to best_weights.h5
# Epoch 3/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 0.0014 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00193
# Epoch 4/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00193 to 0.00192, saving model to best_weights.h5
# Epoch 5/80
# 1712/1712 [==============================] - 1s 302us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00192 to 0.00184, saving model to best_weights.h5
# Epoch 6/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00182, saving model to best_weights.h5
# Epoch 7/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 9.4071e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00182 to 0.00176, saving model to best_weights.h5
# Epoch 8/80
# 1712/1712 [==============================] - 1s 308us/step - loss: 8.2068e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00176 to 0.00171, saving model to best_weights.h5
# Epoch 9/80
# 1712/1712 [==============================] - 1s 306us/step - loss: 7.3207e-04 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00171 to 0.00157, saving model to best_weights.h5
# Epoch 10/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 6.5489e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00157 to 0.00145, saving model to best_weights.h5
# Epoch 11/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 5.9041e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00145 to 0.00134, saving model to best_weights.h5
# Epoch 12/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 5.5341e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00134 to 0.00130, saving model to best_weights.h5
# Epoch 13/80
# 1712/1712 [==============================] - 1s 312us/step - loss: 5.1387e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00130 to 0.00118, saving model to best_weights.h5
# Epoch 14/80
# 1712/1712 [==============================] - 1s 310us/step - loss: 4.7444e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00118 to 0.00110, saving model to best_weights.h5
# Epoch 15/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 4.5087e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00110 to 0.00106, saving model to best_weights.h5
# Epoch 16/80
# 1712/1712 [==============================] - 1s 308us/step - loss: 4.2246e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00106 to 0.00104, saving model to best_weights.h5
# Epoch 17/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 4.0343e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss did not improve from 0.00104
# Epoch 18/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 3.9075e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss improved from 0.00104 to 0.00101, saving model to best_weights.h5
# Epoch 19/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 3.7430e-04 - val_loss: 9.9391e-04
#
# Epoch 00019: val_loss improved from 0.00101 to 0.00099, saving model to best_weights.h5
# Epoch 20/80
# 1712/1712 [==============================] - 1s 295us/step - loss: 3.5648e-04 - val_loss: 9.4602e-04
#
# Epoch 00020: val_loss improved from 0.00099 to 0.00095, saving model to best_weights.h5
# Epoch 21/80
# 1712/1712 [==============================] - 1s 311us/step - loss: 3.4338e-04 - val_loss: 9.7371e-04
#
# Epoch 00021: val_loss did not improve from 0.00095
# Epoch 22/80
# 1712/1712 [==============================] - 1s 315us/step - loss: 3.3445e-04 - val_loss: 9.4883e-04
#
# Epoch 00022: val_loss did not improve from 0.00095
# Epoch 23/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 3.2401e-04 - val_loss: 9.1999e-04
#
# Epoch 00023: val_loss improved from 0.00095 to 0.00092, saving model to best_weights.h5
# Epoch 24/80
# 1712/1712 [==============================] - 1s 306us/step - loss: 3.2479e-04 - val_loss: 9.1428e-04
#
# Epoch 00024: val_loss improved from 0.00092 to 0.00091, saving model to best_weights.h5
# Epoch 25/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 2.9958e-04 - val_loss: 9.0964e-04
#
# Epoch 00025: val_loss improved from 0.00091 to 0.00091, saving model to best_weights.h5
# Epoch 26/80
# 1712/1712 [==============================] - 1s 300us/step - loss: 2.9311e-04 - val_loss: 9.0031e-04
#
# Epoch 00026: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 27/80
# 1712/1712 [==============================] - 1s 304us/step - loss: 2.9883e-04 - val_loss: 9.1393e-04
#
# Epoch 00027: val_loss did not improve from 0.00090
# Epoch 28/80
# 1712/1712 [==============================] - 1s 299us/step - loss: 2.8992e-04 - val_loss: 8.7479e-04
#
# Epoch 00028: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 29/80
# 1712/1712 [==============================] - 1s 314us/step - loss: 2.8051e-04 - val_loss: 8.9630e-04
#
# Epoch 00029: val_loss did not improve from 0.00087
# Epoch 30/80
# 1712/1712 [==============================] - 1s 318us/step - loss: 2.8066e-04 - val_loss: 9.1732e-04
#
# Epoch 00030: val_loss did not improve from 0.00087
# Epoch 31/80
# 1712/1712 [==============================] - 1s 309us/step - loss: 2.6997e-04 - val_loss: 9.0733e-04
#
# Epoch 00031: val_loss did not improve from 0.00087
# Epoch 32/80
# 1712/1712 [==============================] - 1s 302us/step - loss: 2.6211e-04 - val_loss: 8.8137e-04
#
# Epoch 00032: val_loss did not improve from 0.00087
# Epoch 33/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 2.5306e-04 - val_loss: 8.9511e-04
#
# Epoch 00033: val_loss did not improve from 0.00087
# Epoch 34/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 2.4676e-04 - val_loss: 8.5981e-04
#
# Epoch 00034: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 35/80
# 1712/1712 [==============================] - 1s 304us/step - loss: 2.4451e-04 - val_loss: 9.0321e-04
#
# Epoch 00035: val_loss did not improve from 0.00086
# Epoch 36/80
# 1712/1712 [==============================] - 1s 306us/step - loss: 2.5006e-04 - val_loss: 8.7413e-04
#
# Epoch 00036: val_loss did not improve from 0.00086
# Epoch 37/80
# 1712/1712 [==============================] - 1s 310us/step - loss: 2.3412e-04 - val_loss: 8.6674e-04
#
# Epoch 00037: val_loss did not improve from 0.00086
# Epoch 38/80
# 1712/1712 [==============================] - 1s 309us/step - loss: 2.3268e-04 - val_loss: 8.2623e-04
#
# Epoch 00038: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 39/80
# 1712/1712 [==============================] - 1s 302us/step - loss: 2.2741e-04 - val_loss: 8.4804e-04
#
# Epoch 00039: val_loss did not improve from 0.00083
# Epoch 40/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 2.2328e-04 - val_loss: 8.4063e-04
#
# Epoch 00040: val_loss did not improve from 0.00083
# Epoch 41/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 2.2012e-04 - val_loss: 8.6520e-04
#
# Epoch 00041: val_loss did not improve from 0.00083
# Epoch 42/80
# 1712/1712 [==============================] - 1s 306us/step - loss: 2.1626e-04 - val_loss: 8.2203e-04
#
# Epoch 00042: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 43/80
# 1712/1712 [==============================] - 1s 313us/step - loss: 2.1363e-04 - val_loss: 8.4991e-04
#
# Epoch 00043: val_loss did not improve from 0.00082
# Epoch 44/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 2.0448e-04 - val_loss: 8.5004e-04
#
# Epoch 00044: val_loss did not improve from 0.00082
# Epoch 45/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 2.0717e-04 - val_loss: 8.4752e-04
#
# Epoch 00045: val_loss did not improve from 0.00082
# Epoch 46/80
# 1712/1712 [==============================] - 1s 300us/step - loss: 2.0421e-04 - val_loss: 8.6612e-04
#
# Epoch 00046: val_loss did not improve from 0.00082
# Epoch 47/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 2.0024e-04 - val_loss: 8.3101e-04
#
# Epoch 00047: val_loss did not improve from 0.00082
# Epoch 48/80
# 1712/1712 [==============================] - 1s 296us/step - loss: 2.0256e-04 - val_loss: 8.4556e-04
#
# Epoch 00048: val_loss did not improve from 0.00082
# Epoch 49/80
# 1712/1712 [==============================] - 1s 304us/step - loss: 1.9531e-04 - val_loss: 8.7718e-04
#
# Epoch 00049: val_loss did not improve from 0.00082
# Epoch 50/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 1.9404e-04 - val_loss: 8.3979e-04
#
# Epoch 00050: val_loss did not improve from 0.00082
# Epoch 51/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 1.8477e-04 - val_loss: 8.3248e-04
#
# Epoch 00051: val_loss did not improve from 0.00082
# Epoch 52/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.8292e-04 - val_loss: 8.4549e-04
#
# Epoch 00052: val_loss did not improve from 0.00082
# Epoch 53/80
# 1712/1712 [==============================] - 1s 309us/step - loss: 1.8531e-04 - val_loss: 8.5039e-04
#
# Epoch 00053: val_loss did not improve from 0.00082
# Epoch 54/80
# 1712/1712 [==============================] - 1s 312us/step - loss: 1.8241e-04 - val_loss: 8.3326e-04
#
# Epoch 00054: val_loss did not improve from 0.00082
# Epoch 55/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.8808e-04 - val_loss: 8.0468e-04
#
# Epoch 00055: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 56/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 1.8006e-04 - val_loss: 8.4772e-04
#
# Epoch 00056: val_loss did not improve from 0.00080
# Epoch 57/80
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.7805e-04 - val_loss: 8.2465e-04
#
# Epoch 00057: val_loss did not improve from 0.00080
# Epoch 58/80
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.7387e-04 - val_loss: 8.5157e-04
#
# Epoch 00058: val_loss did not improve from 0.00080
# Epoch 59/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.8026e-04 - val_loss: 8.4022e-04
#
# Epoch 00059: val_loss did not improve from 0.00080
# Epoch 60/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.7442e-04 - val_loss: 8.8362e-04
#
# Epoch 00060: val_loss did not improve from 0.00080
# Epoch 61/80
# 1712/1712 [==============================] - 1s 295us/step - loss: 1.6841e-04 - val_loss: 8.5687e-04
#
# Epoch 00061: val_loss did not improve from 0.00080
# Epoch 62/80
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.6566e-04 - val_loss: 8.0495e-04
#
# Epoch 00062: val_loss did not improve from 0.00080
# Epoch 63/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 1.6282e-04 - val_loss: 8.5505e-04
#
# Epoch 00063: val_loss did not improve from 0.00080
# Epoch 64/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.6483e-04 - val_loss: 8.2396e-04
#
# Epoch 00064: val_loss did not improve from 0.00080
# Epoch 65/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.6785e-04 - val_loss: 8.5301e-04
#
# Epoch 00065: val_loss did not improve from 0.00080
# Epoch 66/80
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.5739e-04 - val_loss: 7.9164e-04
#
# Epoch 00066: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 67/80
# 1712/1712 [==============================] - 1s 304us/step - loss: 1.5775e-04 - val_loss: 8.2075e-04
#
# Epoch 00067: val_loss did not improve from 0.00079
# Epoch 68/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 1.5435e-04 - val_loss: 8.1071e-04
#
# Epoch 00068: val_loss did not improve from 0.00079
# Epoch 69/80
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.5730e-04 - val_loss: 8.6879e-04
#
# Epoch 00069: val_loss did not improve from 0.00079
# Epoch 70/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.5645e-04 - val_loss: 8.6101e-04
#
# Epoch 00070: val_loss did not improve from 0.00079
# Epoch 71/80
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.5374e-04 - val_loss: 7.9425e-04
#
# Epoch 00071: val_loss did not improve from 0.00079
# Epoch 72/80
# 1712/1712 [==============================] - 1s 301us/step - loss: 1.5165e-04 - val_loss: 8.4916e-04
#
# Epoch 00072: val_loss did not improve from 0.00079
# Epoch 73/80
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.5311e-04 - val_loss: 8.1721e-04
#
# Epoch 00073: val_loss did not improve from 0.00079
# Epoch 74/80
# 1712/1712 [==============================] - 1s 306us/step - loss: 1.4554e-04 - val_loss: 8.5341e-04
#
# Epoch 00074: val_loss did not improve from 0.00079
# Epoch 75/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 1.4600e-04 - val_loss: 8.2626e-04
#
# Epoch 00075: val_loss did not improve from 0.00079
# Epoch 76/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 1.4735e-04 - val_loss: 8.6705e-04
#
# Epoch 00076: val_loss did not improve from 0.00079
# Epoch 77/80
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.4975e-04 - val_loss: 8.5791e-04
#
# Epoch 00077: val_loss did not improve from 0.00079
# Epoch 78/80
# 1712/1712 [==============================] - 1s 307us/step - loss: 1.4759e-04 - val_loss: 7.8183e-04
#
# Epoch 00078: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 79/80
# 1712/1712 [==============================] - 1s 305us/step - loss: 1.4586e-04 - val_loss: 8.0000e-04
#
# Epoch 00079: val_loss did not improve from 0.00078
# Epoch 80/80
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.4313e-04 - val_loss: 8.3233e-04
#
# Epoch 00080: val_loss did not improve from 0.00078

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
def flip_data(img , points):
  # 左右翻轉即水平翻轉
  # batch_size , h , w
  img = img[: , : , ::-1]
  # 座標修正
  # 水平翻轉不影響y座標
  for i in range(points.shape[0]):
    for j in range(0 , 30 , 2):
      # 座標要記得rescale
      points[i][j] = (img.shape[2] - (points[i][j]+0.5)*96)/96 - 0.5

  return img , points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
plt.imshow(imgs_train[0] , cmap='gray')

# %%
# 增強資料
aug_imgs_train, aug_points_train = flip_data(imgs_train, points_train)
print("圖像資料:", aug_imgs_train.shape, "\n關鍵點資料:", aug_points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
plt.imshow(aug_imgs_train[0] , cmap = 'gray')

# %%
mixed_image = np.concatenate((imgs_train , aug_imgs_train) , axis = 0).reshape(-1 , 96 , 96).astype('float32')
mixed_points = np.concatenate((points_train , aug_points_train) , axis = 0).reshape(-1 , 30).astype('float32')

# %%
mixed_image.shape
# Out:
# (4280, 96, 96)

# %%
mixed_points.shape
# Out:
# (4280, 30)

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# training the model
mixed_checkpoint = ModelCheckpoint('mix_best_weights.h5', verbose=1, save_best_only=True)

mix_hist_model = model_with_augment.fit(mixed_image.reshape(-1, 96, 96, 1), 
                       mixed_points, 
                       validation_split=0.2, batch_size=64,callbacks=[checkpoint],
                       shuffle=True, epochs=100, verbose=1)
# save the model weights
model_with_augment.save_weights('mix_weights.h5')
# save the model
model_with_augment.save('mix_model.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/100
# 3424/3424 [==============================] - 1s 426us/step - loss: 0.0051 - val_loss: 0.0016
#
# Epoch 00001: val_loss did not improve from 0.00078
# Epoch 2/100
# 3424/3424 [==============================] - 1s 303us/step - loss: 0.0015 - val_loss: 0.0016
#
# Epoch 00002: val_loss did not improve from 0.00078
# Epoch 3/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 0.0012 - val_loss: 0.0015
#
# Epoch 00003: val_loss did not improve from 0.00078
# Epoch 4/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 0.0011 - val_loss: 0.0014
#
# Epoch 00004: val_loss did not improve from 0.00078
# Epoch 5/100
# 3424/3424 [==============================] - 1s 290us/step - loss: 9.0897e-04 - val_loss: 0.0014
#
# Epoch 00005: val_loss did not improve from 0.00078
# Epoch 6/100
# 3424/3424 [==============================] - 1s 290us/step - loss: 7.7081e-04 - val_loss: 0.0015
#
# Epoch 00006: val_loss did not improve from 0.00078
# Epoch 7/100
# 3424/3424 [==============================] - 1s 291us/step - loss: 6.7029e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss did not improve from 0.00078
# Epoch 8/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 6.0808e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss did not improve from 0.00078
# Epoch 9/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 5.5524e-04 - val_loss: 0.0018
#
# Epoch 00009: val_loss did not improve from 0.00078
# Epoch 10/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 5.2487e-04 - val_loss: 0.0017
#
# Epoch 00010: val_loss did not improve from 0.00078
# Epoch 11/100
# 3424/3424 [==============================] - 1s 292us/step - loss: 4.8835e-04 - val_loss: 0.0018
#
# Epoch 00011: val_loss did not improve from 0.00078
# Epoch 12/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 4.6402e-04 - val_loss: 0.0018
#
# Epoch 00012: val_loss did not improve from 0.00078
# Epoch 13/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 4.3481e-04 - val_loss: 0.0017
#
# Epoch 00013: val_loss did not improve from 0.00078
# Epoch 14/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 4.1235e-04 - val_loss: 0.0019
#
# Epoch 00014: val_loss did not improve from 0.00078
# Epoch 15/100
# 3424/3424 [==============================] - 1s 290us/step - loss: 4.0399e-04 - val_loss: 0.0019
#
# Epoch 00015: val_loss did not improve from 0.00078
# Epoch 16/100
# 3424/3424 [==============================] - 1s 291us/step - loss: 3.9141e-04 - val_loss: 0.0020
#
# Epoch 00016: val_loss did not improve from 0.00078
# Epoch 17/100
# 3424/3424 [==============================] - 1s 291us/step - loss: 3.7337e-04 - val_loss: 0.0020
#
# Epoch 00017: val_loss did not improve from 0.00078
# Epoch 18/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 3.5167e-04 - val_loss: 0.0019
#
# Epoch 00018: val_loss did not improve from 0.00078
# Epoch 19/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 3.3908e-04 - val_loss: 0.0019
#
# Epoch 00019: val_loss did not improve from 0.00078
# Epoch 20/100
# 3424/3424 [==============================] - 1s 291us/step - loss: 3.3691e-04 - val_loss: 0.0018
#
# Epoch 00020: val_loss did not improve from 0.00078
# Epoch 21/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 3.1548e-04 - val_loss: 0.0019
#
# Epoch 00021: val_loss did not improve from 0.00078
# Epoch 22/100
# 3424/3424 [==============================] - 1s 289us/step - loss: 3.0817e-04 - val_loss: 0.0019
#
# Epoch 00022: val_loss did not improve from 0.00078
# Epoch 23/100
# 3424/3424 [==============================] - 1s 292us/step - loss: 2.9710e-04 - val_loss: 0.0020
#
# Epoch 00023: val_loss did not improve from 0.00078
# Epoch 24/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.9756e-04 - val_loss: 0.0020
#
# Epoch 00024: val_loss did not improve from 0.00078
# Epoch 25/100
# 3424/3424 [==============================] - 1s 301us/step - loss: 2.8865e-04 - val_loss: 0.0019
#
# Epoch 00025: val_loss did not improve from 0.00078
# Epoch 26/100
# 3424/3424 [==============================] - 1s 290us/step - loss: 2.7342e-04 - val_loss: 0.0019
#
# Epoch 00026: val_loss did not improve from 0.00078
# Epoch 27/100
# 3424/3424 [==============================] - 1s 290us/step - loss: 2.6599e-04 - val_loss: 0.0018
#
# Epoch 00027: val_loss did not improve from 0.00078
# Epoch 28/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.6144e-04 - val_loss: 0.0020
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/100
# 3424/3424 [==============================] - 1s 292us/step - loss: 2.5709e-04 - val_loss: 0.0018
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.5415e-04 - val_loss: 0.0020
#
# Epoch 00030: val_loss did not improve from 0.00078
# Epoch 31/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.4613e-04 - val_loss: 0.0020
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/100
# 3424/3424 [==============================] - 1s 302us/step - loss: 2.4045e-04 - val_loss: 0.0020
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.3238e-04 - val_loss: 0.0019
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.3442e-04 - val_loss: 0.0019
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.3108e-04 - val_loss: 0.0019
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 2.2641e-04 - val_loss: 0.0021
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 2.1635e-04 - val_loss: 0.0020
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.1581e-04 - val_loss: 0.0020
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.1243e-04 - val_loss: 0.0019
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.0755e-04 - val_loss: 0.0020
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.0471e-04 - val_loss: 0.0020
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.0112e-04 - val_loss: 0.0021
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/100
# 3424/3424 [==============================] - 1s 304us/step - loss: 2.0030e-04 - val_loss: 0.0019
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/100
# 3424/3424 [==============================] - 1s 301us/step - loss: 2.0082e-04 - val_loss: 0.0020
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.9124e-04 - val_loss: 0.0018
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.9149e-04 - val_loss: 0.0019
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.8392e-04 - val_loss: 0.0020
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.8480e-04 - val_loss: 0.0019
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.7989e-04 - val_loss: 0.0020
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.7487e-04 - val_loss: 0.0019
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.7094e-04 - val_loss: 0.0020
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.7349e-04 - val_loss: 0.0020
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/100
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.7073e-04 - val_loss: 0.0019
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.6937e-04 - val_loss: 0.0019
#
# Epoch 00054: val_loss did not improve from 0.00078
# Epoch 55/100
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.6350e-04 - val_loss: 0.0019
#
# Epoch 00055: val_loss did not improve from 0.00078
# Epoch 56/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.6021e-04 - val_loss: 0.0019
#
# Epoch 00056: val_loss did not improve from 0.00078
# Epoch 57/100
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.6289e-04 - val_loss: 0.0019
#
# Epoch 00057: val_loss did not improve from 0.00078
# Epoch 58/100
# 3424/3424 [==============================] - 1s 293us/step - loss: 1.5961e-04 - val_loss: 0.0019
#
# Epoch 00058: val_loss did not improve from 0.00078
# Epoch 59/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.5677e-04 - val_loss: 0.0019
#
# Epoch 00059: val_loss did not improve from 0.00078
# Epoch 60/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.5228e-04 - val_loss: 0.0019
#
# Epoch 00060: val_loss did not improve from 0.00078
# Epoch 61/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.5223e-04 - val_loss: 0.0019
#
# Epoch 00061: val_loss did not improve from 0.00078
# Epoch 62/100
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.5257e-04 - val_loss: 0.0019
#
# Epoch 00062: val_loss did not improve from 0.00078
# Epoch 63/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.5077e-04 - val_loss: 0.0019
#
# Epoch 00063: val_loss did not improve from 0.00078
# Epoch 64/100
# 3424/3424 [==============================] - 1s 302us/step - loss: 1.4565e-04 - val_loss: 0.0018
#
# Epoch 00064: val_loss did not improve from 0.00078
# Epoch 65/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.4592e-04 - val_loss: 0.0018
#
# Epoch 00065: val_loss did not improve from 0.00078
# Epoch 66/100
# 3424/3424 [==============================] - 1s 300us/step - loss: 1.4351e-04 - val_loss: 0.0019
#
# Epoch 00066: val_loss did not improve from 0.00078
# Epoch 67/100
# 3424/3424 [==============================] - 1s 303us/step - loss: 1.4022e-04 - val_loss: 0.0020
#
# Epoch 00067: val_loss did not improve from 0.00078
# Epoch 68/100
# 3424/3424 [==============================] - 1s 304us/step - loss: 1.4098e-04 - val_loss: 0.0020
#
# Epoch 00068: val_loss did not improve from 0.00078
# Epoch 69/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.3894e-04 - val_loss: 0.0019
#
# Epoch 00069: val_loss did not improve from 0.00078
# Epoch 70/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.3892e-04 - val_loss: 0.0020
#
# Epoch 00070: val_loss did not improve from 0.00078
# Epoch 71/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.3489e-04 - val_loss: 0.0019
#
# Epoch 00071: val_loss did not improve from 0.00078
# Epoch 72/100
# 3424/3424 [==============================] - 1s 306us/step - loss: 1.3243e-04 - val_loss: 0.0018
#
# Epoch 00072: val_loss did not improve from 0.00078
# Epoch 73/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.3345e-04 - val_loss: 0.0019
#
# Epoch 00073: val_loss did not improve from 0.00078
# Epoch 74/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.3224e-04 - val_loss: 0.0019
#
# Epoch 00074: val_loss did not improve from 0.00078
# Epoch 75/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.3016e-04 - val_loss: 0.0019
#
# Epoch 00075: val_loss did not improve from 0.00078
# Epoch 76/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.3459e-04 - val_loss: 0.0018
#
# Epoch 00076: val_loss did not improve from 0.00078
# Epoch 77/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.2877e-04 - val_loss: 0.0018
#
# Epoch 00077: val_loss did not improve from 0.00078
# Epoch 78/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.2792e-04 - val_loss: 0.0019
#
# Epoch 00078: val_loss did not improve from 0.00078
# Epoch 79/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.2516e-04 - val_loss: 0.0018
#
# Epoch 00079: val_loss did not improve from 0.00078
# Epoch 80/100
# 3424/3424 [==============================] - 1s 292us/step - loss: 1.2364e-04 - val_loss: 0.0019
#
# Epoch 00080: val_loss did not improve from 0.00078
# Epoch 81/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.2175e-04 - val_loss: 0.0018
#
# Epoch 00081: val_loss did not improve from 0.00078
# Epoch 82/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.1984e-04 - val_loss: 0.0019
#
# Epoch 00082: val_loss did not improve from 0.00078
# Epoch 83/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.2244e-04 - val_loss: 0.0019
#
# Epoch 00083: val_loss did not improve from 0.00078
# Epoch 84/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.2208e-04 - val_loss: 0.0019
#
# Epoch 00084: val_loss did not improve from 0.00078
# Epoch 85/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.1884e-04 - val_loss: 0.0020
#
# Epoch 00085: val_loss did not improve from 0.00078
# Epoch 86/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.2068e-04 - val_loss: 0.0019
#
# Epoch 00086: val_loss did not improve from 0.00078
# Epoch 87/100
# 3424/3424 [==============================] - 1s 305us/step - loss: 1.1683e-04 - val_loss: 0.0019
#
# Epoch 00087: val_loss did not improve from 0.00078
# Epoch 88/100
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.1492e-04 - val_loss: 0.0018
#
# Epoch 00088: val_loss did not improve from 0.00078
# Epoch 89/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.1663e-04 - val_loss: 0.0018
#
# Epoch 00089: val_loss did not improve from 0.00078
# Epoch 90/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.1310e-04 - val_loss: 0.0020
#
# Epoch 00090: val_loss did not improve from 0.00078
# Epoch 91/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.1245e-04 - val_loss: 0.0018
#
# Epoch 00091: val_loss did not improve from 0.00078
# Epoch 92/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.1343e-04 - val_loss: 0.0018
#
# Epoch 00092: val_loss did not improve from 0.00078
# Epoch 93/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.1089e-04 - val_loss: 0.0019
#
# Epoch 00093: val_loss did not improve from 0.00078
# Epoch 94/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.1239e-04 - val_loss: 0.0018
#
# Epoch 00094: val_loss did not improve from 0.00078
# Epoch 95/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.0957e-04 - val_loss: 0.0019
#
# Epoch 00095: val_loss did not improve from 0.00078
# Epoch 96/100
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.1022e-04 - val_loss: 0.0019
#
# Epoch 00096: val_loss did not improve from 0.00078
# Epoch 97/100
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.1016e-04 - val_loss: 0.0019
#
# Epoch 00097: val_loss did not improve from 0.00078
# Epoch 98/100
# 3424/3424 [==============================] - 1s 301us/step - loss: 1.0806e-04 - val_loss: 0.0019
#
# Epoch 00098: val_loss did not improve from 0.00078
# Epoch 99/100
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.0580e-04 - val_loss: 0.0019
#
# Epoch 00099: val_loss did not improve from 0.00078
# Epoch 100/100
# 3424/3424 [==============================] - 1s 300us/step - loss: 1.0727e-04 - val_loss: 0.0019
#
# Epoch 00100: val_loss did not improve from 0.00078

# %%
plt.title('Optimizer : Adam(aug data)', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(mix_hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(mix_hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
